# %%
# %matplotlib inline 
from lifelines.datasets import load_waltons
df = load_waltons() # returns a Pandas DataFrame

print (df.head())
T = df['T']
E = df['E']

from lifelines import KaplanMeierFitter
kmf = KaplanMeierFitter()
kmf.fit(T, event_observed=E) # more succinctly, kmf.fit(T,E)

kmf.survival_function_
kmf.median_
kmf.plot()


groups = df['group']
ix = (groups == 'miR-137')

kmf.fit(T[~ix], E[~ix], label='control')
ax = kmf.plot()

kmf.fit(T[ix], E[ix], label='miR-137')
kmf.plot(ax=ax)
# Out:
#     T  E    group
# 0   6  1  miR-137
# 1  13  1  miR-137
# 2  13  1  miR-137
# 3  13  1  miR-137
# 4  19  1  miR-137
